# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://meesho.com/elegant-fashionable-women-handbags/p/mqi4q"

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
r=requests.get(url)
htmlContent=r.content
print(htmlContent)
# Out:
# b'<!DOCTYPE html><html lang="en"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2"></script><script async="">\n              window.dataLayer = window.dataLayer || [];\n              function gtag(){dataLayer.push(arguments);}\n              gtag(\'js\', new Date());\n\n              gtag(\'config\', \'UA-113318580-2\', {\n                page_path: window.location.pathname,\n              });\n          </script><script async="">        \n          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n          new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n          j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n          \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n          })(window,document,\'script\',\'dataLayer\',\'GTM-WCJQFLD\');\n          </script><title>Trendy Fashionable Women Handbags</title><meta name="description" content="
# ...

# %%
soup=BeautifulSoup(htmlContent,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-113318580-2">
#   </script>
#   <script async="">
#    window.dataLayer = window.dataLayer || [];
#               function gtag(){dataLayer.push(arguments);}
#               gtag('js', new Date());
#
#               gtag('config', 'UA-113318580-2', {
#                 page_path: window.location.pathname,
#               });
#   </script>
#   <script async="">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-WCJQFLD');
#   </script>
#   <title>
#    Trendy Fashionable Women Handbags
#   </title>
#   <meta content="Material: PU
# ...

# %%
title=soup.title
print(type(soup))
print(type(title))
print(type(title.string))
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %%
print(soup.find('p')['class'])
# Out:
# ['Text__StyledText-sc-oo0kvp-0', 'bWSOET', 'Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0', 'hEkmRy', 'ShippingInfo__ParagraphBody2StrikeThroughStyled-sc-dflqn4-8', 'cnLyze', 'Paragraph__StyledParagraphBody2StrikeThrough-sc-69qp0d-0', 'hEkmRy', 'ShippingInfo__ParagraphBody2StrikeThroughStyled-sc-dflqn4-8', 'cnLyze']

# %%
# scraped_name=soup.find_all('span',class_='Text__StyledText-sc-oo0kvp-0 elstub')
# scraped_name

# %%
names=[]
for name in scraped_name:
    name=name.get_text().replace('\n',"")
    name=name.strip(" ")
    names.append(name)
names

# %%
name=soup.find('span',class_='Text__StyledText-sc-oo0kvp-0 elstub')
name.text
# Out:
# 'Trendy Fashionable Women Handbags'

# %%
scraped_price=soup.find_all('h4', class_="Text__StyledText-sc-oo0kvp-0 fyTUEs")
scraped_price
# Out:
# [<h4 class="Text__StyledText-sc-oo0kvp-0 fyTUEs" color="greyBase" font-size="32px" font-weight="bold">₹<!-- -->192</h4>,
#  <h4 class="Text__StyledText-sc-oo0kvp-0 fyTUEs" color="greyBase" font-size="32px" font-weight="bold">Shop Non-Stop on Meesho</h4>]

# %%
# prices=[]
# for price in scraped_price:
#     price=price.get_text()
#     price=price.strip()
#     prices.append(price)
# prices

# %%
prices=soup.find('h4', class_="Text__StyledText-sc-oo0kvp-0 fyTUEs")
prices.text
# Out:
# '₹192'

# %%
scraped_discount=soup.find_all('span', class_="Text__StyledText-sc-oo0kvp-0 jENgNp")
scraped_discount
# Out:
# [<span class="Text__StyledText-sc-oo0kvp-0 jENgNp" color="greenBase" font-size="18px" font-weight="demi">30<!-- -->% off</span>]

# %%
# discounts=[]
# for discount in scraped_discount:
#     discount=discount.get_text().replace('\n',"")
#     discount=discount.strip(" ")
#     discounts.append(discount)
# discounts

# %%
discounts=soup.find('span', class_="Text__StyledText-sc-oo0kvp-0 jENgNp")
discounts.text
# Out:
# '30% off'
